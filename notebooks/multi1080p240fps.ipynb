# %% [markdown]
# # MultiVideo Training, with Emphasis on 45 degree Diagonal View
# https://github.com/vjann/DLC
#
# ### Description:
# Used 3 diagonal clips of reaching and one head-on video to train a mouse reaching network. Body parts: left eye, nose, hand, index, middle, ring, pinky, pellet.

# %% [markdown]
# ## Create a new project
#
# Keep the projects separate. This function creates a new project with subdirectories and a basic configuration file under DeepLabCut directory.
# You can add new videos to the project at any stage of the project.

# %%
import datetime
import deeplabcut

# %%
task='multi-diagonal' # Enter the name of your experiment Task
experimenter='vj' # Enter the name of the experimenter
video=[r"C:\Users\vjj14\Downloads\diag2_Trim.mp4", r"C:\Users\vjj14\Downloads\diag2_Trim2.mp4", r"C:\Users\vjj14\Downloads\diagonal1080p240fps_Trim.mp4", r"C:\Users\vjj14\Downloads\diagonalzoom1080p240fps_Trim.mp4"] # Enter the paths of your videos you want to grab frames from.
path_config_file=deeplabcut.create_new_project(task,experimenter,video, working_directory= r'C:\Users\vjj14\Desktop\DeepLabCut',copy_videos=True) #change the working directory to where you want the folders created.
# The function returns the path, where your project is.
# Out:
# Created "C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-12\videos"
# Created "C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-12\labeled-data"
# Created "C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-12\training-datasets"
# Created "C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-12\dlc-models"
# Copying the videos
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-12\videos\diag2_Trim.mp4
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-12\videos\diag2_Trim2.mp4
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-12\videos\diagonal1080p240fps_Trim.mp4
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-12\videos\diagonalzoom1080p240fps_Trim.mp4
# Generated "C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-12\config.yaml"
#
# A new project with name multi-diagonal-vj-2019-06-12 is created at C:\Users\vjj14\Desktop\DeepLabCut and a configurable file (config.yaml) is stored there. Change the parameters in this file to adapt to your project's needs.
#  Once you have changed the configuration file, use the function 'extract_frames' to select frames for labeling.
# . [OPTIONAL] Use the function 'add_new_videos' to add new videos to your project (at any stage).

# %%
path_config_file= r"C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\config.yaml"
project_name='multidiagonal'
def write_log(text, new_line=True):
    time_log= open("{0}log{1}.txt".format(path_config_file[:-11], project_name),"a+")
    if new_line:
        time_log.write("\n")
    time_log.write(text)
    time_log.close()
    print("log written")

# %%
from time import sleep
def prompt_with_timeout(prompt_message):
  print('Waiting... please press Ctrl-C when you wish to proceed.')
  try:
    for i in range(0, 2*60): # 2 minutes
      sleep(1)
    return "No Input Received"
  except KeyboardInterrupt:
    return input(prompt_message)

# %% [markdown]
# ## Extract frames from videos
# Select diverse frames, which are typical for the behavior you study that should be labeled.
# (algo=='uniform') selects N frames either uniformly sampled from a particular video (or folder) . Note: this might not yield diverse frames, if the behavior is sparsely distributed (consider using kmeans), and/or select frames manually etc.
# Individual images should not be too big (i.e. < 850 x 850 pixel). Although this can be taken care of later, crop the frames to remove unnecessary parts.
# Always check the output of cropping.

# %%
deeplabcut.add_new_videos(path_config_file, [r"C:\Users\vjj14\Downloads\1080p_Trim2.mp4"], copy_videos=True)
# Out:
# Copying the videos
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.

# %%
# ?deeplabcut.add_new_videos

# %%
start = datetime.datetime.now()
write_log(str(start) + "***extract_frames start")

# %matplotlib inline
deeplabcut.extract_frames(path_config_file,'automatic','uniform',crop=True) #there are other ways to grab frames, such as by clustering 'kmeans'; please see the paper. 

end = datetime.datetime.now()
write_log(str(end) + "***extract_frames end")
write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# Config file read successfully.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim.mp4 ?
# yes/nono
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim2.mp4 ?
# yes/nono
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diagonal1080p240fps_Trim.mp4 ?
# yes/nono
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diagonalzoom1080p240fps_Trim.mp4 ?
# yes/nono
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\1080p_Trim2.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 6.43  seconds.
#
# Frames were selected.
# You can now label the frames using the function 'label_frames' (if you extracted enough frames for all videos).
# log written
# log written

# %%
# ?deeplabcut.extract_frames

# %% [markdown]
# ## Label the extracted frames
# Only videos in the config file can be used to extract the frames. Extracted labels for each video are stored in the project directory under the subdirectory **'labeled-data'**. Each subdirectory is named after the name of the video. The toolbox has a labeling toolbox which could be used for labeling.

# %%
start = datetime.datetime.now()
write_log(str(start) + "***label_frames start")

# %gui wx
deeplabcut.label_frames(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***label_frames end")
write_log("   time elapsed:" + str(end-start))

# %% [markdown]
# **Check the labels**
#
# Checking if the labels were created and stored correctly is beneficial for training, since labeling is one of the most critical parts for creating the training dataset.

# %%
deeplabcut.check_labels(path_config_file) #this creates a subdirectory with the frames + your labels
# Out:
# Creating images with labels by vj.
# They are stored in the following folder: C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\labeled-data\diag2_Trim_labeled.
# They are stored in the following folder: C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\labeled-data\diag2_Trim2_labeled.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.FileIO object at 0x000001ED860D97E0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-7-3e88fa872e76> in <module>()
# ----> 1 deeplabcut.check_labels(path_config_file) #this creates a subdirectory with the frames + your labels
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\generate_training_dataset\trainingsetmanipulation.py in check_labels(config, Labels, scale)
#     256         try:
#     257             DataCombined = pd.read_hdf(os.path.join(str(folder),'CollectedData_' + cfg['scorer'] + '.h5'), 'df_with_missing')
# --> 258             MakeLabeledPlots(folder,DataCombined,cfg,Labels,Colorscheme,cc,scale)
#     259         except FileNotFoundError:
#     260             print("Attention:", folder, "does not appear to have labeled data!")
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\generate_training_dataset\trainingsetmanipulation.py in MakeLabeledPlots(folder, DataCombined, cfg, Labels, Colorscheme, cc, scale)
#     299         plt.gca().invert_yaxis()
#     300
# --> 301         plt.savefig(str(Path(tmpfolder)/imagename.split(os.sep)[-1])) #create file name
#     302         plt.close("all")
#     303
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\matplotlib\figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     521                 cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     522             _png.write_png(renderer._renderer, fh,
# --> 523                             self.figure.dpi, metadata=metadata)
#     524
#     525     def print_to_buffer(self):
#
# SystemError: <built-in method write of _io.BufferedWriter object at 0x000001EDECCC45C8> returned a result with an error set

# %% [markdown]
# If the labels need adjusted, you can use the refinement GUI to move them around! Check that out below.

# %% [markdown]
# ## Create a training dataset
# This function generates the training data information for DeepCut (which requires a mat file) based on the pandas dataframes that hold label information. The user can set the fraction of the training set size (from all labeled image in the hd5 file) in the config.yaml file. While creating the dataset, the user can create multiple shuffles.
#
# After running this script the training dataset is created and saved in the project directory under the subdirectory **'training-datasets'**
#
# This function also creates new subdirectories under **dlc-models** and appends the project config.yaml file with the correct path to the training and testing pose configuration file. These files hold the parameters for training the network. Such an example file is provided with the toolbox and named as **pose_cfg.yaml**.

# %%
start = datetime.datetime.now()
write_log(str(start) + "***create_training_dataset start")

deeplabcut.create_training_dataset(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***create_training_dataset end")
write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!
# log written
# log written

# %%
# ?deeplabcut.create_training_dataset

# %% [markdown]
# ## Start training - If you want to use a CPU, continue.
# ### If you want to use your GPU, you need to exit here and either work from the Docker container, your own TensorFlow installation in an Anaconda env
#
# This function trains the network for a specific shuffle of the training dataset.

# %%
start = datetime.datetime.now()
write_log(str(start) + "***train_network start")
write_log("   DESCRIPTION:" + prompt_with_timeout("Training description(Network, Iterations, etc) "))

deeplabcut.train_network(path_config_file, saveiters=1000, displayiters=100, maxiters=30001)

end = datetime.datetime.now()
write_log(str(end) + "***train_network end")
write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# Waiting... please press Ctrl-C when you wish to proceed.
# Training description(Network, Iterations, etc) for 2nd network, 30k iters, jump alg outliers
# log written
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['leftEye',
#                       'nose',
#                       'hand',
#                       'index',
#                       'middle',
#                       'ring',
#                       'pinky',
#                       'pellet'],
#  'batch_size': 1,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\multi-diagonal_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\Documentation_data-multi-diagonal_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\dlc-models\\iteration-1\\multi-diagonalJun10-trainset90shuffle1\\train\\snapshot',
#  'stride': 8.0,
#  'topheight': 400,
#  'use_gt_segm': False,
#  'video': False,
#  'video_batch': False,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\pose_estimation_tensorflow\models\pretrained\resnet_v1_50.ckpt
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\pose_estimation_tensorflow\models\pretrained\resnet_v1_50.ckpt
# Max_iters overwritten as 30001
# Display_iters overwritten as 100
# Save_iters overwritten as 1000
# Training parameter:
# {'stride': 8.0, 'weigh_part_predictions': False, 'weigh_negatives': False, 'fg_fraction': 0.25, 'weigh_only_present_joints': False, 'mean_pixel': [123.68, 116.779, 103.939], 'shuffle': True, 'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\dlc-models\\iteration-1\\multi-diagonalJun10-trainset90shuffle1\\train\\snapshot', 'log_dir': 'log', 'global_scale': 0.8, 'location_refinement': True, 'locref_stdev': 7.2801, 'locref_loss_weight': 0.05, 'locref_huber_loss': True, 'optimizer': 'sgd', 'intermediate_supervision': False, 'intermediate_supervision_layer': 12, 'regularize': False, 'weight_decay': 0.0001, 'mirror': False, 'crop_pad': 0, 'scoremap_dir': 'test', 'dataset_type': 'default', 'use_gt_segm': False, 'batch_size': 1, 'video': False, 'video_batch': False, 'crop': True, 'cropratio': 0.4, 'minsize': 100, 'leftwidth': 400, 'rightwidth': 400, 'topheight': 400, 'bottomheight': 400, 'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]], 'all_joints_names': ['leftEye', 'nose', 'hand', 'index', 'middle', 'ring', 'pinky', 'pellet'], 'dataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\multi-diagonal_vj90shuffle1.mat', 'display_iters': 1000, 'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt', 'max_input_size': 1500, 'metadataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\Documentation_data-multi-diagonal_90shuffle1.pickle', 'min_input_size': 64, 'multi_step': [[0.005, 10000], [0.02, 430000], [0.002, 730000], [0.001, 1030000]], 'net_type': 'resnet_50', 'num_joints': 8, 'pos_dist_thresh': 17, 'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10', 'save_iters': 50000, 'scale_jitter_lo': 0.5, 'scale_jitter_up': 1.25}
# Starting training....
# iteration: 100 loss: 0.0734 lr: 0.005
# iteration: 200 loss: 0.0211 lr: 0.005
# iteration: 300 loss: 0.0204 lr: 0.005
# iteration: 400 loss: 0.0191 lr: 0.005
# iteration: 500 loss: 0.0179 lr: 0.005
# iteration: 600 loss: 0.0179 lr: 0.005
# iteration: 700 loss: 0.0161 lr: 0.005
# iteration: 800 loss: 0.0143 lr: 0.005
# iteration: 900 loss: 0.0138 lr: 0.005
# iteration: 1000 loss: 0.0143 lr: 0.005
# iteration: 1100 loss: 0.0126 lr: 0.005
# iteration: 1200 loss: 0.0130 lr: 0.005
# iteration: 1300 loss: 0.0137 lr: 0.005
# iteration: 1400 loss: 0.0132 lr: 0.005
# iteration: 1500 loss: 0.0120 lr: 0.005
# iteration: 1600 loss: 0.0129 lr: 0.005
# iteration: 1700 loss: 0.0110 lr: 0.005
# iteration: 1800 loss: 0.0111 lr: 0.005
# iteration: 1900 loss: 0.0118 lr: 0.005
# iteration: 2000 loss: 0.0109 lr: 0.005
# iteration: 2100 loss: 0.0103 lr: 0.005

#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tensorflow\python\client\session.py", line 1348, in _do_call
#     raise type(e)(node_def, op, message)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[node fifo_queue_enqueue (defined at C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\pose_estimation_tensorflow\train.py:39)  = QueueEnqueueV2[Tcomponents=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](fifo_queue, _arg_Placeholder_0_0, _arg_Placeholder_1_0_1, _arg_Placeholder_2_0_2, _arg_Placeholder_3_0_3, _arg_Placeholder_4_0_4)]]
#
# Caused by op 'fifo_queue_enqueue', defined at:
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tornado\platform\asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\asyncio\base_events.py", line 1434, in _run_once
#     handle._run()
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tornado\ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tornado\gen.py", line 1233, in inner
#     self.run()
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tornado\gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\IPython\core\interactiveshell.py", line 2683, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\IPython\core\interactiveshell.py", line 2787, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\IPython\core\interactiveshell.py", line 2847, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-82db7e18a6ad>", line 5, in <module>
#     deeplabcut.train_network(path_config_file, saveiters=1000, displayiters=100, maxiters=30001)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\pose_estimation_tensorflow\training.py", line 87, in train_network
#     train(str(poseconfigfile),displayiters,saveiters,maxiters,max_to_keep=max_snapshots_to_keep) #pass on path and file name for pose_cfg.yaml!
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\pose_estimation_tensorflow\train.py", line 88, in train
#     batch, enqueue_op, placeholders = setup_preloading(batch_spec)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\pose_estimation_tensorflow\train.py", line 39, in setup_preloading
#     enqueue_op = q.enqueue(placeholders_list)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tensorflow\python\ops\data_flow_ops.py", line 341, in enqueue
#     self._queue_ref, vals, name=scope)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tensorflow\python\ops\gen_data_flow_ops.py", line 3984, in queue_enqueue_v2
#     timeout_ms=timeout_ms, name=name)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tensorflow\python\util\deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tensorflow\python\framework\ops.py", line 3274, in create_op
#     op_def=op_def)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tensorflow\python\framework\ops.py", line 1770, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[node fifo_queue_enqueue (defined at C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\pose_estimation_tensorflow\train.py:39)  = QueueEnqueueV2[Tcomponents=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](fifo_queue, _arg_Placeholder_0_0, _arg_Placeholder_1_0_1, _arg_Placeholder_2_0_2, _arg_Placeholder_3_0_3, _arg_Placeholder_4_0_4)]]
# The network is now trained and ready to evaluate. Use the function 'evaluate_network' to evaluate the network.
# log written
# log written

# %%
# ?deeplabcut.train_network

# %% [markdown]
# ## Start evaluating
# This funtion evaluates a trained model for a specific shuffle/shuffles at a particular state or all the states on the data set (images)
# and stores the results as .csv file in a subdirectory under **evaluation-results**

# %%
start = datetime.datetime.now()
write_log(str(start) + "***evaluate_network start")

deeplabcut.evaluate_network(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***evaluate_network end")
write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10/evaluation-results/  already exists!
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['leftEye',
#                       'nose',
#                       'hand',
#                       'index',
#                       'middle',
#                       'ring',
#                       'pinky',
#                       'pellet'],
#  'batch_size': 1,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\multi-diagonal_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\Documentation_data-multi-diagonal_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\dlc-models\\iteration-1\\multi-diagonalJun10-trainset90shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'topheight': 400,
#  'use_gt_segm': False,
#  'video': False,
#  'video_batch': False,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Running  DeepCut_resnet50_multi-diagonalJun10shuffle1_30001  with # of trainingiterations: 30001
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1\train\snapshot-30001
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1\train\snapshot-30001
# Analyzing data...
# 157it [00:21,  8.31it/s]
# Done and results stored for snapshot:  snapshot-30001
# Results for 30001  training iterations: 90 1 train error: 4.05 pixels. Test error: 8.44  pixels.
# With pcutoff of 0.1  train error: 4.05 pixels. Test error: 7.38 pixels
# Thereby, the errors are given by the average distances between the labels by DLC and the scorer.
# The network is evaluated and the results are stored in the subdirectory 'evaluation_results'.
# If it generalizes well, choose the best model for prediction and update the config file with the appropriate index for the 'snapshotindex'.
# Use the function 'analyze_video' to make predictions on new videos.
# Otherwise consider retraining the network (see DeepLabCut workflow Fig 2)
# log written
# log written

# %% [markdown]
# ## Start Analyzing videos
# This function analyzes the new video. The user can choose the best model from the evaluation results and specify the correct snapshot index for the variable **snapshotindex** in the **config.yaml** file. Otherwise, by default the most recent snapshot is used to analyse the video.
#
# The results are stored in hd5 file in the same directory where the video resides.

# %%
path_config_file
# Out:
# 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\config.yaml'

# %%
# videofile_path = [r"C:\Users\vjj14\Downloads\compressed25.mp4"] #Enter the list of videos to analyze.
videos=[[r"C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\1080p_Trim2.mp4"], [r"C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim.mp4"], [r"C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim2.mp4"], [r"C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diagonal1080p240fps_Trim.mp4"], [r"C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diagonalzoom1080p240fps_Trim.mp4"]]
for videofile_path in videos:
    start = datetime.datetime.now()
    write_log(str(start) + "***analyze_videos start")
    write_log("   VIDEO: " + str(videofile_path))

    deeplabcut.analyze_videos(path_config_file,videofile_path, save_as_csv=True)

    end = datetime.datetime.now()
    write_log(str(end) + "***analyze_videos end")
    write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# log written
#  98%|████████████████████████████████████████████████████████████████████████████▋ | 3762/3824 [05:30<00:05, 11.69it/s]Exception in thread Thread-12:
# Traceback (most recent call last):
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\iostream.py", line 97, in _event_pipe
#     event_pipe = self._local.event_pipe
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tqdm\_monitor.py", line 92, in run
#     instance.refresh(nolock=True)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tqdm\_tqdm.py", line 1200, in refresh
#     self.display()
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tqdm\_tqdm.py", line 1323, in display
#     self.sp(self.__repr__() if msg is None else msg)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tqdm\_tqdm.py", line 250, in print_status
#     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tqdm\_tqdm.py", line 243, in fp_write
#     fp.write(_unicode(s))
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\colorama\ansitowin32.py", line 41, in write
#     self.__convertor.write(text)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\colorama\ansitowin32.py", line 162, in write
#     self.write_and_convert(text)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\colorama\ansitowin32.py", line 190, in write_and_convert
#     self.write_plain_text(text, cursor, len(text))
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\colorama\ansitowin32.py", line 195, in write_plain_text
#     self.wrapped.write(text[start:end])
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\iostream.py", line 400, in write
#     self.pub_thread.schedule(lambda : self._buffer.write(string))
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\iostream.py", line 203, in schedule
#     self._event_pipe.send(b'')
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\iostream.py", line 101, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\zmq\sugar\context.py", line 146, in socket
#     s = self._socket_class(self, socket_type, **kwargs)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\zmq\sugar\socket.py", line 59, in __init__
#     super(Socket, self).__init__(*a, **kw)
#   File "zmq/backend/cython/socket.pyx", line 328, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: No buffer space available
# Unhandled exception in thread started by <bound method Thread._bootstrap of <TMonitor(Thread-12, started daemon 7188)>>
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['leftEye',
#                       'nose',
#                       'hand',
#                       'index',
#                       'middle',
#                       'ring',
#                       'pinky',
#                       'pellet'],
#  'batch_size': 4,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\multi-diagonal_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\Documentation_data-multi-diagonal_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\dlc-models\\iteration-1\\multi-diagonalJun10-trainset90shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'topheight': 400,
#  'use_gt_segm': False,
#  'video': False,
#  'video_batch': False,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Using snapshot-30000 for model C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1\train\snapshot-30000
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1\train\snapshot-30000
# Starting to analyze %  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\1080p_Trim2.mp4
# Loading  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\1080p_Trim2.mp4
# Duration of video [s]:  6.43 , recorded with  30.0 fps!
# Overall # of frames:  193  found with (before cropping) frame dimensions:  1920 1080
# Starting to extract posture
#   0%|                                                                                          | 0/193 [00:00<?, ?it/s]
#  10%|████████▍                                                                        | 20/193 [00:01<00:09, 17.95it/s]
#  16%|████████████▌                                                                    | 30/193 [00:02<00:11, 14.48it/s]
#  21%|████████████████▊                                                                | 40/193 [00:02<00:10, 14.10it/s]
#  26%|████████████████████▉                                                            | 50/193 [00:03<00:11, 12.43it/s]
#  31%|█████████████████████████▏                                                       | 60/193 [00:04<00:10, 12.76it/s]
#  36%|█████████████████████████████▍                                                   | 70/193 [00:05<00:10, 11.67it/s]
#  41%|█████████████████████████████████▌                                               | 80/193 [00:06<00:09, 12.15it/s]
#  47%|█████████████████████████████████████▊                                           | 90/193 [00:07<00:09, 11.23it/s]
#  52%|█████████████████████████████████████████▍                                      | 100/193 [00:08<00:07, 11.73it/s]
#  57%|█████████████████████████████████████████████▌                                  | 110/193 [00:09<00:07, 10.95it/s]
#  62%|█████████████████████████████████████████████████▋                              | 120/193 [00:09<00:06, 11.69it/s]
#  67%|█████████████████████████████████████████████████████▉                          | 130/193 [00:11<00:05, 10.92it/s]
#  73%|██████████████████████████████████████████████████████████                      | 140/193 [00:11<00:04, 11.62it/s]
#  78%|██████████████████████████████████████████████████████████████▏                 | 150/193 [00:12<00:03, 10.86it/s]
#  83%|██████████████████████████████████████████████████████████████████▎             | 160/193 [00:13<00:02, 11.50it/s]
#  88%|██████████████████████████████████████████████████████████████████████▍         | 170/193 [00:14<00:02, 10.96it/s]
#  93%|██████████████████████████████████████████████████████████████████████████▌     | 180/193 [00:15<00:01, 11.71it/s]
#  98%|██████████████████████████████████████████████████████████████████████████████▊ | 190/193 [00:16<00:00, 10.98it/s]
# 200it [00:17, 11.65it/s]
# Detected frames:  193
# Saving results in C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'.
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract any outlier frames!
# log written
# log written
# log written
# log written
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['leftEye',
#                       'nose',
#                       'hand',
#                       'index',
#                       'middle',
#                       'ring',
#                       'pinky',
#                       'pellet'],
#  'batch_size': 4,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\multi-diagonal_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\Documentation_data-multi-diagonal_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\dlc-models\\iteration-1\\multi-diagonalJun10-trainset90shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'topheight': 400,
#  'use_gt_segm': False,
#  'video': False,
#  'video_batch': False,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Using snapshot-30000 for model C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1\train\snapshot-30000
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1\train\snapshot-30000
# Starting to analyze %  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim.mp4
# Loading  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\vide
#  82%|█████████████████████████████████████████████████████████████████▋              | 380/463 [00:31<00:06, 12.24it/s]
#  84%|███████████████████████████████████████████████████████████████████▍            | 390/463 [00:32<00:06, 11.33it/s]
#  86%|█████████████████████████████████████████████████████████████████████           | 400/463 [00:33<00:05, 11.91it/s]
#  89%|██████████████████████████████████████████████████████████████████████▊         | 410/463 [00:34<00:04, 11.27it/s]
#  91%|████████████████████████████████████████████████████████████████████████▌       | 420/463 [00:35<00:03, 12.11it/s]
#  93%|██████████████████████████████████████████████████████████████████████████▎     | 430/463 [00:36<00:02, 11.62it/s]
#  95%|████████████████████████████████████████████████████████████████████████████    | 440/463 [00:36<00:01, 12.12it/s]
#  97%|█████████████████████████████████████████████████████████████████████████████▊  | 450/463 [00:37<00:01, 11.40it/s]
#  99%|███████████████████████████████████████████████████████████████████████████████▍| 460/463 [00:38<00:00, 12.00it/s]
# 470it [00:39, 11.36it/s]
# Detected frames:  463
# Saving results in C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'.
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract any outlier frames!
# log written
# log written
# log written
# log written
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['leftEye',
#                       'nose',
#                       'hand',
#                       'index',
#                       'middle',
#                       'ring',
#                       'pinky',
#                       'pellet'],
#  'batch_size': 4,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\multi-diagonal_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\Documentation_data-multi-diagonal_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\dlc-models\\iteration-1\\multi-diagonalJun10-trainset90shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'topheight': 400,
#  'use_gt_segm': False,
#  'video': False,
#  'video_batch': False,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Using snapshot-30000 for model C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1\train\snapshot-30000
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1\train\snapshot-30000
# Starting to analyze %  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim2.mp4
# Loading  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim2.mp4
# Duration of video [s]:  8.0 , recorded with  30.0 fps!
# Overall # of frames:  240  found with (before cropping) frame dimensions:  1080 1920
# Starting to extract posture
#   0%|                                                                                          | 0/240 [00:00<?, ?it/s]
#   8%|██████▊                                                                          | 20/240 [00:01<00:11, 18.77it/s]
#  12%|██████████▏                                                                      | 30/240 [00:02<00:14, 14.75it/s]
#  17%|█████████████▌                                                                   | 40/240 [00:02<00:13, 14.62it/s]
#  21%|████████████████▉                                                                | 50/240 [00:03<00:14, 12.85it/s]
#  25%|████████████████████▎                                                            | 60/240 [00:04<00:13, 13.04it/s]
#  29%|███████████████████████▋                                                         | 70/240 [00:05<00:14, 12.07it/s]
#  33%|███████████████████████████                                                      | 80/240 [00:06<00:12, 12.76it/s]
#  38%|██████████████████████████████▍                                                  | 90/240 [00:07<00:12, 11.63it/s]
#  42%|█████████████████████████████████▎                                              | 100/240 [00:07<00:11, 12.28it/s]
#  46%|████████████████████████████████████▋                                           | 110/240 [00:08<00:11, 11.46it/s]
#  50%|████████████████████████████████████████                                        | 120/240 [00:09<00:09, 12.03it/s]
#  54%|███████████████████████████████████████████▎                                    | 130/240 [00:10<00:09, 11.28it/s]
#  58%|██████████████████████████████████████████████▋                                 | 140/240 [00:11<00:08, 12.07it/s]
#  62%|██████████████████████████████████████████████████                              | 150/240 [00:12<00:07, 11.38it/s]
#  67%|█████████████████████████████████████████████████████▎                          | 160/240 [00:13<00:06, 12.05it/s]
#  71%|████████████████████████████████████████████████████████▋                       | 170/240 [00:14<00:06, 11.53it/s]
#  75%|████████████████████████████████████████████████████████████                    | 180/240 [00:14<00:04, 12.31it/s]
#  79%|███████████████████████████████████████████████████████████████▎                | 190/240 [00:15<00:04, 11.48it/s]
#  83%|██████████████████████████████████████████████████████████████████▋             | 200/240 [00:16<00:03, 12.14it/s]
#  88%|██████████████████████████████████████████████████████████████████████          | 210/240 [00:17<00:02, 11.51it/s]
#  92%|█████████████████████████████████████████████████████████████████████████▎      | 220/240 [00:18<00:01, 12.09it/s]
#  96%|████████████████████████████████████████████████████████████████████████████▋   | 230/240 [00:19<00:00, 11.56it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 240/240 [00:19<00:00, 12.16it/s]
# 250it [00:20, 11.49it/s]
# Detected frames:  240
# Saving results in C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'.
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract any outlier frames!
# log written
# log written
# log written
# log written
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['leftEye',
#                       'nose',
#                       'hand',
#                       'index',
#                       'middle',
#                       'ring',
#                       'pinky',
#                       'pellet'],
#  'batch_size': 4,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\multi-diagonal_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\Documentation_data-multi-diagonal_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\dlc-models\\iteration-1\\multi-diagonalJun10-trainset90shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'topheight': 400,
#  'use_gt_segm': False,
#  'video': False,
#  'video_batch': False,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Using snapshot-30000 for model C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1\train\snapshot-30000
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\dlc-models\iteration-1\multi-diagonalJun10-trainset90shuffle1\train\snapshot-30000
# Starting to analyze %  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diagonal1080p240fps_Trim.mp4
# Loading  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diagonal1080p240fps_Trim.mp4
# Duration of video [s]:  127.47 , recorded with  30.0 fps!
# Overall # of frames:  3824  found with (before cropping) frame dimensions:  1080 1920
# Starting to extract posture
#   0%|                                                                                         | 0/3824 [00:00<?, ?it/s]
#   2%|█▌                                                                              | 76/3824 [00:03<02:47, 22.43it/s]
#   3%|██▎                                                                            | 114/3824 [00:06<03:31, 17.53it/s]
#   4%|███▏                                                                           | 152/3824 [00:09<03:52, 15.81it/s]
#   5%|███▉                                                                           | 190/3824 [00:12<04:16, 14.18it/s]
#   6%|████▋                                                                          | 228/3824 [00:15<04:22, 13.69it/s]
#   7%|█████▍                                                                         | 266/3824 [00:19<04:32, 13.06it/s]
#   8%|██████▎                                                                        | 304/3824 [00:22<04:31, 12.99it/s]
#   9%|███████                                                                        | 342/3824 [00:25<04:35, 12.66it/s]
#  10%|███████▊                                                                       | 380/3824 [00:28<04:32, 12.64it/s]
#  11%|████████▋                                                                      | 418/3824 [00:31<04:37, 12.26it/s]
#  12%|█████████▍                                                                     | 456/3824 [00:34<04:34, 12.28it/s]
#  13%|██████████▏                                                                    | 494/3824 [00:38<04:38, 11.94it/s]
#  14%|██████████▉                                                                    | 532/3824 [00:41<04:32, 12.08it/s]
#  82%|████████████████████████████████████████████████████████████████▎             | 3154/3824 [04:18<00:55, 11.99it/s]
#  83%|█████████████████████████████████████████████████████████████████             | 3192/3824 [04:21<00:51, 12.17it/s]
#  84%|█████████████████████████████████████████████████████████████████▉            | 3230/3824 [04:24<00:49, 11.93it/s]
#  85%|██████████████████████████████████████████████████████████████████▋           | 3268/3824 [04:27<00:45, 12.16it/s]
#  86%|███████████████████████████████████████████████████████████████████▍          | 3306/3824 [04:31<00:42, 12.05it/s]
#  87%|████████████████████████████████████████████████████████████████████▏         | 3344/3824 [04:34<00:39, 12.28it/s]
#  88%|████████████████████████████████████████████████████████████████████▉         | 3382/3824 [04:37<00:36, 12.02it/s]
#  89%|█████████████████████████████████████████████████████████████████████▊        | 3420/3824 [04:40<00:33, 12.24it/s]
#  90%|██████████████████████████████████████████████████████████████████████▌       | 3458/3824 [04:43<00:30, 11.99it/s]
#  91%|███████████████████████████████████████████████████████████████████████▎      | 3496/3824 [04:46<00:26, 12.19it/s]
#  92%|████████████████████████████████████████████████████████████████████████      | 3534/3824 [04:49<00:24, 11.97it/s]
#  93%|████████████████████████████████████████████████████████████████████████▊     | 3572/3824 [04:53<00:20, 12.12it/s]
#  94%|█████████████████████████████████████████████████████████████████████████▋    | 3610/3824 [04:56<00:18, 11.85it/s]
#  95%|██████████████████████████████████████████████████████████████████████████▍   | 3648/3824 [04:59<00:14, 12.08it/s]
#  96%|███████████████████████████████████████████████████████████████████████████▏  | 3686/3824 [05:02<00:11, 11.89it/s]
#  97%|███████████████████████████████████████████████████████████████████████████▉  | 3724/3824 [05:05<00:08, 12.08it/s]
#  98%|████████████████████████████████████████████████████████████████████████████▋ | 3762/3824 [05:09<00:05, 11.85it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▌| 3800/3824 [05:12<00:01, 12.08it/s]
# 3838it [05:15, 11.90it/s]
# Detected frames:  3824
# Saving results in C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'.
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract any outlier frames!
# log written
# log written
# log written
# log written
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['leftEye',
#                       'nose',
#                       'hand',
#                       'index',
#                       'middle',
#                       'ring',
#                       'pinky',
#                       'pellet'],
#  'batch_size': 4,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\multi-diagonal_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-1\\UnaugmentedDataSet_multi-diagonalJun10\\Documentation_data-multi-diagonal_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix
#  92%|███████████████████████████████████████████████████████████████████████▍      | 2484/2714 [03:19<00:18, 12.26it/s]
#  93%|████████████████████████████████████████████████████████████████████████▏     | 2511/2714 [03:22<00:16, 12.25it/s]
#  94%|████████████████████████████████████████████████████████████████████████▉     | 2538/2714 [03:24<00:13, 12.71it/s]
#  95%|█████████████████████████████████████████████████████████████████████████▋    | 2565/2714 [03:26<00:12, 12.41it/s]
#  96%|██████████████████████████████████████████████████████████████████████████▍   | 2592/2714 [03:28<00:09, 12.29it/s]
#  96%|███████████████████████████████████████████████████████████████████████████▎  | 2619/2714 [03:30<00:07, 12.14it/s]
#  97%|████████████████████████████████████████████████████████████████████████████  | 2646/2714 [03:32<00:05, 12.63it/s]
#  98%|████████████████████████████████████████████████████████████████████████████▊ | 2673/2714 [03:35<00:03, 12.43it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▌| 2700/2714 [03:37<00:01, 12.30it/s]
# 2727it [03:39, 12.10it/s]
# Detected frames:  2714
# Saving results in C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'.
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract any outlier frames!
# log written
# log written

# %%
# ?deeplabcut.analyze_videos

# %% [markdown]
# ## Extract outlier frames [optional step]
# This is an optional step and is used only when the evaluation results are poor i.e. the labels are incorrectly predicted. In such a case, the user can use the following function to extract frames where the labels are incorrectly predicted. Make sure to provide the correct value of the "iterations" as it will be used to create the unique directory where the extracted frames will be saved.

# %%
vid = [r"C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim2.mp4"]
alg = 'jump'
param = 300 #epsilon or p_bound

start = datetime.datetime.now()
write_log(str(start) + "***extract_outlier_frames start")

deeplabcut.extract_outlier_frames(path_config_file, vid, outlieralgorithm=alg, epsilon=param)
num_frames = prompt_with_timeout("number of frames selected?")
write_log("   VIDEOS: {0}, ALGORITHM: {1}, PARAMETER: {2}, NUM FRAMES: {3}".format(str(vid), alg, param, num_frames))

end = datetime.datetime.now()
write_log(str(end) + "***analyze_videos end")
write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# network parameters: DeepCut_resnet50_multi-diagonalJun10shuffle1_30001
# Method  jump  found  48  putative outlier frames.
# Do you want to proceed with extracting  60  of those?
# If this list is very large, perhaps consider changing the paramters (start, stop, epsilon, comparisonbodyparts) or use a different method.
# yes/noyes
# Frames from video diag2_Trim2  already extracted (more will be added)!
# Loading video...
# Duration of video [s]:  8.0 , recorded @  30.0 fps!
# Overall # of frames:  240 with (cropped) frame dimensions:
# Kmeans-quantization based extracting of frames from 0.0  seconds to 8.0  seconds.
# Let's select frames indices: [11, 12, 14, 16, 17, 20, 22, 23, 24, 25, 33, 34, 35, 36, 42, 45, 46, 47, 48, 54, 55, 60, 61, 62, 63, 69, 71, 72, 73, 74, 75, 86, 128, 129, 153, 154, 155, 156, 157, 158, 162, 163, 164, 165, 188, 189, 237, 238]
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# The outlier frames are extracted. They are stored in the subdirectory labeled-data\diag2_Trim2.
# Once you extracted frames for all videos, use 'refine_labels' to manually correct the labels.
# Waiting... please press Ctrl-C when you wish to proceed.
# number of frames selected?48
# log written
# log written
# log written

# %%
# ?deeplabcut.extract_outlier_frames

# %% [markdown]
# ## Refine Labels [optional step]
# Following the extraction of outlier frames, the user can use the following function to move the predicted labels to the correct location. Thus augmenting the training dataset.

# %%
start = datetime.datetime.now()
write_log(str(start) + "***refine_frames start")

# %gui wx
deeplabcut.refine_labels(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***refine_frames end")
write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# ERROR:root:Cannot activate multiple GUI eventloops
# Windows
# Checking labels if they are outside the image
# A training dataset file is already found for this video. The refined machine labels are merged to this data!
# Closing... The refined labels are stored in a subdirectory under labeled-data. Use the function 'merge_datasets' to augment the training dataset, and then re-train a network using create_training_dataset followed by train_network!
# log written
# log written

# %%
#Once all folders are relabeled, check them and advance. See how to check labels, above!
start = datetime.datetime.now()
write_log(str(start) + "***mergedatasets start")

deeplabcut.merge_datasets(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***mergedatasets end")
write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# Merged data sets and updated refinement iteration to 1.
# Now you can create a new training set for the expanded annotated images (use create_training_dataset).
# log written
# log written

# %% [markdown]
# ## Create a new iteration of training dataset [optional step]
# Following the refine labels, append these frames to the original dataset to create a new iteration of training dataset.

# %%
start = datetime.datetime.now()
write_log(str(start) + "***create_training_dataset start")

deeplabcut.create_training_dataset(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***create_training_dataset end")
write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!
# log written
# log written

# %% [markdown]
# ## Create labeled video
# This funtion is for visualiztion purpose and can be used to create a video in .mp4 format with labels predicted by the network. This video is saved in the same directory where the original video resides.

# %%
# videos=[LIST OF VIDEOS]
for videofile_path in videos:
    start = datetime.datetime.now()
    write_log(str(start) + "***create_labeled_video start")
    write_log("   VIDEOS: {}".format(str(videofile_path)))

    deeplabcut.create_labeled_video(path_config_file,videofile_path)

    end = datetime.datetime.now()
    write_log(str(end) + "***create_labeled_video end")
    write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# log written
# Starting %  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos ['C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\videos\\1080p_Trim2.mp4']
# Loading  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\1080p_Trim2.mp4 and data.
# False 0 1920 0 1080
# 193
# Duration of video [s]:  6.43 , recorded with  30.0 fps!
# Overall # of frames:  193 with cropped frame dimensions:  1920 1080
# Generating frames and creating video.
#   0%|                                                                                          | 0/193 [00:00<?, ?it/s]
#   2%|█▋                                                                                | 4/193 [00:00<00:05, 37.48it/s]
#   6%|████▌                                                                            | 11/193 [00:00<00:04, 43.25it/s]
#   9%|███████▌                                                                         | 18/193 [00:00<00:03, 48.47it/s]
#  13%|██████████▍                                                                      | 25/193 [00:00<00:03, 52.83it/s]
/s]
#  94%|█████████████████████████████████████████████████████████████████████████▍    | 2557/2714 [00:44<00:02, 54.35it/s]
#  94%|█████████████████████████████████████████████████████████████████████████▋    | 2563/2714 [00:44<00:02, 54.90it/s]
#  95%|█████████████████████████████████████████████████████████████████████████▊    | 2569/2714 [00:44<00:02, 55.29it/s]
#  95%|██████████████████████████████████████████████████████████████████████████    | 2575/2714 [00:44<00:02, 55.26it/s]
#  95%|██████████████████████████████████████████████████████████████████████████▏   | 2581/2714 [00:44<00:02, 56.17it/s]
#  95%|██████████████████████████████████████████████████████████████████████████▎   | 2587/2714 [00:44<00:02, 56.50it/s]
#  96%|██████████████████████████████████████████████████████████████████████████▌   | 2593/2714 [00:44<00:02, 57.06it/s]
#  96%|██████████████████████████████████████████████████████████████████████████▋   | 2599/2714 [00:45<00:01, 57.62it/s]
#  96%|██████████████████████████████████████████████████████████████████████████▊   | 2605/2714 [00:45<00:01, 58.19it/s]
#  96%|███████████████████████████████████████████████████████████████████████████   | 2611/2714 [00:45<00:01, 57.92it/s]
#  96%|███████████████████████████████████████████████████████████████████████████▏  | 2617/2714 [00:45<00:01, 58.23it/s]
#  97%|███████████████████████████████████████████████████████████████████████████▍  | 2623/2714 [00:45<00:01, 58.12it/s]
#  97%|███████████████████████████████████████████████████████████████████████████▌  | 2629/2714 [00:45<00:01, 58.54it/s]
#  97%|███████████████████████████████████████████████████████████████████████████▋  | 2635/2714 [00:45<00:01, 58.33it/s]
#  97%|███████████████████████████████████████████████████████████████████████████▉  | 2641/2714 [00:45<00:01, 55.45it/s]
#  98%|████████████████████████████████████████████████████████████████████████████  | 2647/2714 [00:45<00:01, 52.89it/s]
#  98%|████████████████████████████████████████████████████████████████████████████▏ | 2653/2714 [00:46<00:01, 54.58it/s]
#  98%|████████████████████████████████████████████████████████████████████████████▍ | 2659/2714 [00:46<00:00, 55.99it/s]
#  98%|████████████████████████████████████████████████████████████████████████████▌ | 2665/2714 [00:46<00:00, 57.01it/s]
#  98%|████████████████████████████████████████████████████████████████████████████▊ | 2671/2714 [00:46<00:00, 57.76it/s]
#  99%|████████████████████████████████████████████████████████████████████████████▉ | 2678/2714 [00:46<00:00, 58.70it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▏| 2685/2714 [00:46<00:00, 59.23it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▎| 2692/2714 [00:46<00:00, 59.76it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▌| 2698/2714 [00:46<00:00, 59.52it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████▋| 2705/2714 [00:46<00:00, 59.82it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████▉| 2712/2714 [00:47<00:00, 60.02it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2714/2714 [00:47<00:00, 57.68it/s]
# log written
# log written

# %%
# ?deeplabcut.create_labeled_video

# %% [markdown]
# ## Plot the trajectories of the analyzed videos
# This function plots the trajectories of all the body parts across the entire video. Each body part is identified by a unique color.

# %%
videofile_path
# Out:
# ['C:\\Users\\vjj14\\Desktop\\DeepLabCut\\frontslowmo-vj-2019-06-05\\videos\\1080p.MOV']

# %%
# %matplotlib notebook 
#for making interactive plots.
for videofile_path in videos:
    deeplabcut.plot_trajectories(path_config_file,videofile_path)
# Out:
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\1080p_Trim2.mp4
# Starting %  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos ['C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\videos\\1080p_Trim2.mp4']
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\plot-poses  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\plot-poses\1080p_Trim2  already exists!
# Loading  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\1080p_Trim2.mp4 and data.
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="2999.9999349767527">
# <img src="data:image/png;base64,..." width="2999.9999349767527">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Plots created! Please check the directory "plot-poses" within the video directory
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim.mp4
# Starting %  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos ['C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\videos\\diag2_Trim.mp4']
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\plot-poses  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\plot-poses\diag2_Trim  already exists!
# Loading  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim.mp4 and data.
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="2999.9999349767527">
# <img src="data:image/png;base64,..." width="2999.9999349767527">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Plots created! Please check the directory "plot-poses" within the video directory
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim2.mp4
# Starting %  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos ['C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\videos\\diag2_Trim2.mp4']
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\plot-poses  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\plot-poses\diag2_Trim2  already exists!
# Loading  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diag2_Trim2.mp4 and data.
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="2999.9999349767527">
# <img src="data:image/png;base64,..." width="2999.9999349767527">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Plots created! Please check the directory "plot-poses" within the video directory
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diagonal1080p240fps_Trim.mp4
# Starting %  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos ['C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\videos\\diagonal1080p240fps_Trim.mp4']
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\plot-poses  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\plot-poses\diagonal1080p240fps_Trim  already exists!
# Loading  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diagonal1080p240fps_Trim.mp4 and data.
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="2999.9999349767527">
# <img src="data:image/png;base64,..." width="2999.9999349767527">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Plots created! Please check the directory "plot-poses" within the video directory
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diagonalzoom1080p240fps_Trim.mp4
# Starting %  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos ['C:\\Users\\vjj14\\Desktop\\DeepLabCut\\multi-diagonal-vj-2019-06-10\\videos\\diagonalzoom1080p240fps_Trim.mp4']
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\plot-poses  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\plot-poses\diagonalzoom1080p240fps_Trim  already exists!
# Loading  C:\Users\vjj14\Desktop\DeepLabCut\multi-diagonal-vj-2019-06-10\videos\diagonalzoom1080p240fps_Trim.mp4 and data.
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="2999.9999349767527">
# <img src="data:image/png;base64,..." width="2999.9999349767527">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Plots created! Please check the directory "plot-poses" within the video directory

# %%
# ?deeplabcut.plot_trajectories

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pandas analysis of Data

# %%
df = pd.read_hdf(r"PATH TO .h5 FILE")
df.head(5)
# Out:
# scorer    DeepCut_resnet50_frontslowmoJun5shuffle1_30000                \
# bodyparts                                       LeftHand
# coords                                                 x             y
# count                                       15560.000000  15560.000000
# mean                                          971.243753    725.853752
# std                                           171.896374    139.390499
# min                                            -3.870381      0.415488
# 25%                                           914.894261    649.265245
# 50%                                          1024.541650    783.569860
# 75%                                          1064.598903    821.210082
# max                                          1611.307688   1088.421771
#
# scorer                                                             \
# bodyparts                   RightHand
# coords       likelihood             x             y    likelihood
# count      15560.000000  15560.000000  15560.000000  15560.000000
# mean           0.699717    906.089441    738.766505      0.503567
# std            0.357561    156.673818    166.830793      0.400728
# min            0.000027    319.477097      1.081914      0.000040
# 25%            0.397388    850.580156    651.611459      0.060324
# 50%            0.910440    905.468754    778.514918      0.466857
# 75%            0.986921    940.134475    858.174915      0.949224
# max            0.999329   1609.412701   1092.391703      0.999041
#
# scorer                                                             \
# bodyparts          Nose                                    Pellet
# coords                x             y    likelihood             x
# count      15560.000000  15560.000000  15560.000000  15560.000000
# mean         931.766309    656.488581      0.671245    957.103689
# std          169.306891    191.976523      0.363396    159.386299
# min          298.748627     -0.059892      0.000104     -5.040360
# 25%          909.805872    595.394240      0.306699    922.235798
# 50%          918.396317    703.317179      0.875269    939.903313
# 75%          928.343641    794.728728      0.960582    953.739810
# max         1623.930874   1088.734671      0.998151   1613.409633
#
# scorer
# bodyparts
# coords                y    likelihood
# count      15560.000000  15560.000000
# mean         811.306070      0.322458
# std          177.523694      0.418997
# min            0.012989      0.000098
# 25%          671.503496      0.027885
# 50%          847.006353      0.048265
# 75%          940.497040      0.954270
# max         1089.468144      0.997180

# %%
df.describe()
# Out:
# scorer    DeepCut_resnet50_front4k60fpszoom3.0_TrimJun3shuffle1_286000  \
# bodyparts                                                     LeftHand
# coords                                                               x
# count                                             612.000000
# mean                                             1294.587569
# std                                               566.489027
# min                                                -0.173059
# 25%                                               955.338525
# 50%                                              1458.549845
# 75%                                              1644.293059
# max                                              2161.044888
#
# scorer                                                                    \
# bodyparts                             RightHand
# coords               y  likelihood            x            y  likelihood
# count       612.000000  612.000000   612.000000   612.000000  612.000000
# mean       2455.822662    0.042246   609.627308  2811.817150    0.078364
# std         890.589556    0.138305   523.969844   763.555947    0.202453
# min           1.988913    0.000032     0.665848    76.401595    0.000153
# 25%        1989.080632    0.000861     3.883312  2168.396138    0.001087
# 50%        2089.116435    0.002397   764.576838  2395.076544    0.003136
# 75%        3421.296761    0.011128   970.543810  3556.132724    0.019450
# max        3840.645847    0.977641  2139.572770  3840.410774    0.992057
#
# scorer                                                                     \
# bodyparts         Nose                                Pellet
# coords               x            y  likelihood            x            y
# count       612.000000   612.000000  612.000000   612.000000   612.000000
# mean       1000.140640  2138.825481    0.222379  1161.420468  3607.459208
# std         249.147238   615.631056    0.313997   635.214989   435.197877
# min           0.269251   865.347540    0.000097     2.184450  1940.036492
# 25%         990.724893  1820.097459    0.004228   736.731850  3637.395378
# 50%        1030.763698  1986.446780    0.050586   963.540944  3822.212681
# 75%        1069.846140  2166.098999    0.300523  1822.975545  3837.997508
# max        2152.967607  3841.093842    0.998524  2158.995823  3841.865475
#
# scorer
# bodyparts
# coords     likelihood
# count      612.000000
# mean         0.364173
# std          0.308807
# min          0.000428
# 25%          0.070970
# 50%          0.276980
# 75%          0.658898
# max          0.989263
