# %% [markdown]
# # PROJECT NAME
# https://github.com/vjann/DLC
#
# ### Description:
# INSERT DESCRIPTION HERE

# %% [markdown]
# ## Create a new project
#
# Keep the projects separate. This function creates a new project with subdirectories and a basic configuration file under DeepLabCut directory.
# You can add new videos to the project at any stage of the project.

# %%
import datetime
import deeplabcut
from time import sleep
import numpy as np

# %%
task='gopro3lens' # Enter the name of your experiment Task
experimenter='vj' # Enter the name of the experimenter
video=[r"C:\Users\vjj14\Documents\GoProLens\3lens\gp2.7k3lensA.MP4"] # Enter the paths of your videos you want to grab frames from.
path_config_file=deeplabcut.create_new_project(task,experimenter,video, working_directory= r'C:\Users\vjj14\Desktop\DeepLabCut',copy_videos=False) #change the working directory to where you want the folders created.
# The function returns the path, where your project is.

# %%
path_config_file= r"C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\config.yaml"
project_name='gopro3lens'
def write_log(text, new_line=True):
    time_log= open("{0}log{1}.txt".format(path_config_file[:-11], project_name),"a+")
    if new_line:
        time_log.write("\n")
    time_log.write(text)
    time_log.close()
    print("log written")
    
def prompt_with_timeout(prompt_message):
  print('Waiting... please press Ctrl-C when you wish to proceed.')
  try:
    for i in range(0, 2*60): # 2 minutes
      sleep(1)
    return "No Input Received"
  except KeyboardInterrupt:
    return input(prompt_message)

# %% [markdown]
# ## Extract frames from videos
# Select diverse frames, which are typical for the behavior you study that should be labeled.
# (algo=='uniform') selects N frames either uniformly sampled from a particular video (or folder) . Note: this might not yield diverse frames, if the behavior is sparsely distributed (consider using kmeans), and/or select frames manually etc.
# Individual images should not be too big (i.e. < 850 x 850 pixel). Although this can be taken care of later, crop the frames to remove unnecessary parts.
# Always check the output of cropping.

# %%
reaches = [19.12, 23.752, 24.186, 24.630, 36.846, 43.652, 44.042, 46.964, 60.218, 62.897, 64.787, 72.045, 85.174, 88.196, 
           91.652, 93.248, 93.814, 106.294, 106.867, 111.344, 112.249, 113.407, 115.474, 115.918, 129.119, 136.837, 138.581]

# %%
reaches = [0.353, 12.325, 16.568, 17.55, 18.912, 20.41, 22.1, 22.92, 24.699, 27.4, 29.754, 30.431, 31.39, 32.692, 37.731, 
           38.258, 42.86, 45.714, 56.45, 76.803, 77.86, 86.2, 86.75, 91.13, 91.649, 97.563, 98.1, 106.739, 107.292, 116.412, 
           121.49, 122.236, 124.775, 125.375, 134.324, 134.859, 142.37, 143.0, 150.0, 150.955, 159.435, 160.04, 165.02, 
           165.633, 174.018, 177.129, 179.23, 183.719, 185.755, 192.041, 197.214, 198.66, 201.286, 203.34, 204.15, 206.253, 
           209.36, 213.027, 213.895, 217.676, 218.325, 218.982, 223.198, 226.56, 230.524, 233.61, 234.286, 235.838, 236.316, 
           237.091, 250.448, 251.206, 253.05]
reaches_labels = ['r', 's', 'r', 'f', 'r', 'r', 'f', 'r', 'r', 'r', 'f', 'r', 'r', 'r?', 'f', 'r', 'r', 's', 'r', 'f', 'r', 
                  'f', 'r', 'f', 'r', 'f', 'r', 'f', 'r', 'f?', 'r', 'r', 'f', 'r', 'f', 'r', 'f', 'r', 'f', '?', 'f', 'r', 
                  'f', 'r', 's', 'r', 's', 'f', 'r', 's', 'f', 'r', 'f', 'r', 'r', 's', 'r', 'f', 'r', 'r', 'f', 'r', 's', 
                  'r', 's', 'r', 'r', 'f', 'f', 'f?', 'f', 'r', 'r']
#2019.07.08_CC42970_N3_V3_2.7k_120FPS_Label
reaches2 = [11.59, 17.76, 18.47, 20.81, 22.45, 25.49, 37.40, 41.88, 51.55, 57.35, 64.50, 78.54, 84.61, 
            96.27, 108.61, 117.01, 123.13, 130.13, 157.55, 164.34, 207.55]
vids2 = ['11.59.mp4', '17.76.mp4', '18.47.mp4', '20.81.mp4', '22.45.mp4', '25.49.mp4', '37.4.mp4', '41.88.mp4', '51.55.mp4', 
         '57.35.mp4', '64.5.mp4', '78.54.mp4', '84.61.mp4', '96.27.mp4', '108.61.mp4', '117.01.mp4', '123.13.mp4', 
         '130.13.mp4', '157.55.mp4', '164.34.mp4', '207.55.mp4']
#2019.07.08_CC42973_N2INJURED_V3_2.7k_120FPS_Label
reaches3 = [21.19, 66.49, 71.22, 85.34, 92.22, 99.69, 116.29, 127.70, 135.33, 142.42, 147.11, 
                   151.60, 157.72, 163.40, 172.79, 183.10, 204.05, 208.73, 216.32]
vids3 = ['21.19.mp4', '66.49.mp4', '71.22.mp4', '85.34.mp4', '92.22.mp4', '99.69.mp4', '116.29.mp4', '127.7.mp4', 
         '135.33.mp4', '142.42.mp4', '147.11.mp4', '151.6.mp4', '157.72.mp4', '163.4.mp4', '172.79.mp4', '183.1.mp4', 
         '204.05.mp4', '208.73.mp4', '216.32.mp4']
s = [reaches[i] for i in range(len(reaches)) if reaches_labels[i] == 's']
r = [reaches[i] for i in range(len(reaches)) if reaches_labels[i] == 'r']
f = [reaches[i] for i in range(len(reaches)) if reaches_labels[i] == 'f']

# %%
#turns seconds into a string format ffmpeg uses
def seconds_formatter(sec):
    x = "0" + str(datetime.timedelta(seconds=sec))[:-3]
    return x

#Open up new batch file
bat_file= path_config_file[:-11] + "videos\{}_create_videos.bat".format(project_name)
script_writer= open(bat_file,"w")

# script_writer.write('if not exist "{}" mkdir {}'.format(path_config_file[:-11] + "vid_clips"))

#write series of shell commands to create videos for each attempt, connected by '&&' for the batch file
vids = []
for time in s + f:
    start_time = seconds_formatter(max(0, time - 1.25))
    cmd = "ffmpeg -i 2019.07.08_CC42970_N2_V3_2.7k_120FPS_Label.mp4 -ss {0} -t {1} -c copy {2}.mp4".format(start_time, 2, np.round(time, 3))
    vids.append(str(np.round(time, 3)) + ".mp4")
    script_writer.write(cmd + " && ")
script_writer.close()

#open and write a list of videos to concatenate (.txt file) for ffmpeg to use
list_file = path_config_file[:-11] + "videos\{}_video_list.txt".format(project_name)
list_writer = open(list_file, "w+")
for v in vids:
    list_writer.write('file ' + "\'" + path_config_file +"videos\{}".format(v) + "\'\n")
list_writer.close()

#open batch file again and write command to produce a concatenated video, the final product
script_writer = open(bat_file, "a+")
script_writer.write("ffmpeg -f concat -safe 0 -i {0} -c copy output2.mp4".format(list_file))
script_writer.close()

# %%
for v in vids3:
    print(v)
    deeplabcut.add_new_videos(path_config_file, [path_config_file[:-11] + "videos\{}".format(v)])
# Out:
# 21.19.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 66.49.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 71.22.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 85.34.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 92.22.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 99.69.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 116.29.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 127.7.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 135.33.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 142.42.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 147.11.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 151.6.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 157.72.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 163.4.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 172.79.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 183.1.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 204.05.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 208.73.mp4
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# 216.32.mp4
# Creating the symbolic link of the video
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\create_project\add.py in add_new_videos(config, videos, copy_videos, coords)
#      86 # For windows os.path.realpath does not work and does not link to the real video.
# ---> 87            video_path = str(Path.resolve(Path(video)))
#      88 #           video_path = os.path.realpath(video)
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\pathlib.py in resolve(self, strict)
#    1138             self._raise_closed()
# -> 1139         s = self._flavour.resolve(self, strict=strict)
#    1140         if s is None:
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\pathlib.py in resolve(self, path, strict)
#     192                     try:
# --> 193                         s = self._ext_to_normal(_getfinalpathname(s))
#     194                     except FileNotFoundError:
#
# OSError: [WinError 1921] The name of the file cannot be resolved by the system: 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08\\videos\\216.32.mp4'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-33408a1a0bfd> in <module>()
#       1 for v in vids3:
#       2     print(v)
# ----> 3     deeplabcut.add_new_videos(path_config_file, [path_config_file[:-11] + "videos\{}".format(v)])
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\create_project\add.py in add_new_videos(config, videos, copy_videos, coords)
#      88 #           video_path = os.path.realpath(video)
#      89         except:
# ---> 90            video_path = os.readlink(video)
#      91
#      92         vcap = cv2.VideoCapture(video_path)
#
# TypeError: readlink() argument 1 must be str, not WindowsPath

# %%
# ?deeplabcut.add_new_videos

# %%
path_config_file[:-11] + r"videos\n3v3\{}".format('11.59.mp4')
# Out:
# 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08\\videos\\n3v3\\11.59.mp4'

# %%
start = datetime.datetime.now()
write_log(str(start) + "***extract_frames start")

# %matplotlib inline
deeplabcut.extract_frames(path_config_file,'automatic','uniform',crop=False) #there are other ways to grab frames, such as by clustering 'kmeans'; please see the paper. 

end = datetime.datetime.now()
write_log(str(end) + "***extract_frames end")
write_log("   time elapsed:" + str(end-start))
write_log("     " + prompt_with_timeout("number of frames selected?") + "frames labeled")
# Out:
# log written
# Config file read successfully.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Documents\GoProLens\3lens\gp2.7k3lensA.MP4 ?
# yes/noN
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\19.12.mp4 ?
# yes/noN
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\23.752.mp4 ?
# yes/noN
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\24.186.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\24.63.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\36.846.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\43.652.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\44.042.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\46.964.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\60.218.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\62.897.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\64.787.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\72.045.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\85.174.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\88.196.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\91.652.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\93.248.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\93.814.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\106.294.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\111.344.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\112.249.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\113.407.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\115.474.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\115.918.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\129.119.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\136.837.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\138.581.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\106.867.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\12.325.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\45.714.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\174.018.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\179.23.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\192.041.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\206.253.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\223.198.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\230.524.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\17.55.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\22.1.mp4 ?
# yes/no
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\29.754.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.98  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\37.731.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.95  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\76.803.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.99  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\86.2.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.87  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\91.13.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.79  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\97.563.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.72  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\106.739.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.89  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\124.775.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.9  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\134.324.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.94  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\142.37.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.99  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\150.0.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.6  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\159.435.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.53  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\165.02.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.61  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\183.719.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.79  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\197.214.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.77  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\201.286.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.84  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\213.027.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.57  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\218.325.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.86  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\235.838.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.86  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\236.316.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.84  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\250.448.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.95  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\11.59.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.84  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\17.76.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.99  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\18.47.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.71  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\20.81.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.54  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\22.45.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.69  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\25.49.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.72  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\37.4.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.62  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\41.88.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.59  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\51.55.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.75  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\57.35.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.55  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\64.5.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.69  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\78.54.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.72  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\84.61.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.78  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\96.27.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.93  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\108.61.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.76  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\117.01.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.65  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\123.13.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.76  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\130.13.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.75  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\157.55.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.65  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\164.34.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.94  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\207.55.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.6  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\21.19.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.93  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\66.49.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.68  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\71.22.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.9  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\85.34.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.51  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\92.22.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.89  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\99.69.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.84  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\116.29.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.93  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\127.7.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.83  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\135.33.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.95  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\142.42.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.53  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\147.11.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.72  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\151.6.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.7  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\157.72.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.82  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\163.4.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.99  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\172.79.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.87  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\183.1.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.67  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\204.05.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.6  seconds.
# Do you want to extract (perhaps additional) frames for video: C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos\208.73.mp4 ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 1.78  seconds.
#
# Frames were selected.
# You can now label the frames using the function 'label_frames' (if you extracted enough frames for all videos).
# log written
# log written
# Waiting... please press Ctrl-C when you wish to proceed.
# number of frames selected?180 from each clip then cut down to 15-40
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8b7f4fb534f5> in prompt_with_timeout(prompt_message)
#      14     for i in range(0, 2*60): # 2 minutes
# ---> 15       sleep(1)
#      16     return "No Input Received"
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\jupyter_client\session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\zmq\sugar\socket.py in recv_multipart(self, flags, copy, track)
#     466         """
# --> 467         parts = [self.recv(flags, copy=copy, track=track)]
#     468         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-152c1e8e4b4a> in <module>()
#       8 write_log(str(end) + "***extract_frames end")
#       9 write_log("   time elapsed:" + str(end-start))
# ---> 10 write_log("     " + prompt_with_timeout("number of frames selected?") + "frames labeled")
#
# <ipython-input-2-8b7f4fb534f5> in prompt_with_timeout(prompt_message)
#      16     return "No Input Received"
#      17   except KeyboardInterrupt:
# ---> 18     return input(prompt_message)
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:

# %%
# ?deeplabcut.extract_frames

# %% [markdown]
# ## Label the extracted frames
# Only videos in the config file can be used to extract the frames. Extracted labels for each video are stored in the project directory under the subdirectory **'labeled-data'**. Each subdirectory is named after the name of the video. The toolbox has a labeling toolbox which could be used for labeling.

# %%
start = datetime.datetime.now()
write_log(str(start) + "***label_frames start")

# %gui wx
deeplabcut.label_frames(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***label_frames end")
write_log("   time elapsed:" + str(end-start))

# %% [markdown]
# **Check the labels**
#
# Checking if the labels were created and stored correctly is beneficial for training, since labeling is one of the most critical parts for creating the training dataset.

# %%
deeplabcut.check_labels(path_config_file) #this creates a subdirectory with the frames + your labels

# %% [markdown]
# If the labels need adjusted, you can use the refinement GUI to move them around! Check that out below.

# %% [markdown]
# ## Create a training dataset
# This function generates the training data information for DeepCut (which requires a mat file) based on the pandas dataframes that hold label information. The user can set the fraction of the training set size (from all labeled image in the hd5 file) in the config.yaml file. While creating the dataset, the user can create multiple shuffles.
#
# After running this script the training dataset is created and saved in the project directory under the subdirectory **'training-datasets'**
#
# This function also creates new subdirectories under **dlc-models** and appends the project config.yaml file with the correct path to the training and testing pose configuration file. These files hold the parameters for training the network. Such an example file is provided with the toolbox and named as **pose_cfg.yaml**.

# %%
start = datetime.datetime.now()
write_log(str(start) + "***create_training_dataset start")

deeplabcut.create_training_dataset(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***create_training_dataset end")
write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\training-datasets\iteration-0\UnaugmentedDataSet_gopro3lensJul8  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\gp2.7k3lensA/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\24.186/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\24.63/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\44.042/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\46.964/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\62.897/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\72.045/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\88.196/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\93.248/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\93.814/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\106.294/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\111.344/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\112.249/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\113.407/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\115.918/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\136.837/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\labeled-data\138.581/CollectedData_vj.h5  not found (perhaps not annotated)
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\dlc-models\iteration-0\gopro3lensJul8-trainset90shuffle1  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\dlc-models\iteration-0\gopro3lensJul8-trainset90shuffle1//train  already exists!
# C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\dlc-models\iteration-0\gopro3lensJul8-trainset90shuffle1//test  already exists!
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!
# log written
# log written

# %%
# ?deeplabcut.create_training_dataset

# %% [markdown]
# ## Start training - If you want to use a CPU, continue.
# ### If you want to use your GPU, you need to exit here and either work from the Docker container, your own TensorFlow installation in an Anaconda env
#
# This function trains the network for a specific shuffle of the training dataset.

# %%
start = datetime.datetime.now()
write_log(str(start) + "***train_network start")
write_log("   DESCRIPTION:" + prompt_with_timeout("Training description(Network, Iterations, etc) "))

deeplabcut.train_network(path_config_file, saveiters=1000, displayiters=100, maxiters=120000)

end = datetime.datetime.now()
write_log(str(end) + "***train_network end")
write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# Waiting... please press Ctrl-C when you wish to proceed.
# Training description(Network, Iterations, etc) same
# log written
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7], [8]],
#  'all_joints_names': ['Nose',
#                       'Pellet',
#                       'DomInside',
#                       'DomOutside',
#                       'Index',
#                       'Middle',
#                       'Ring',
#                       'Pinky',
#                       'OtherHand'],
#  'batch_size': 1,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_gopro3lensJul8\\gopro3lens_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_gopro3lensJul8\\Documentation_data-gopro3lens_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 9,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08\\dlc-models\\iteration-0\\gopro3lensJul8-trainset90shuffle1\\train\\snapshot',
#  'stride': 8.0,
#  'topheight': 400,
#  'use_gt_segm': False,
#  'video': False,
#  'video_batch': False,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\deeplabcut\pose_estimation_tensorflow\models\pretrained\resnet_v1_50.ckpt
# Max_iters overwritten as 120000
# Display_iters overwritten as 100
# Save_iters overwritten as 1000
# Training parameter:
# {'stride': 8.0, 'weigh_part_predictions': False, 'weigh_negatives': False, 'fg_fraction': 0.25, 'weigh_only_present_joints': False, 'mean_pixel': [123.68, 116.779, 103.939], 'shuffle': True, 'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08\\dlc-models\\iteration-0\\gopro3lensJul8-trainset90shuffle1\\train\\snapshot', 'log_dir': 'log', 'global_scale': 0.8, 'location_refinement': True, 'locref_stdev': 7.2801, 'locref_loss_weight': 0.05, 'locref_huber_loss': True, 'optimizer': 'sgd', 'intermediate_supervision': False, 'intermediate_supervision_layer': 12, 'reg

#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tensorflow\python\client\session.py", line 929, in run
#     run_metadata_ptr)
#   File "C:\Users\vjj14\.conda\envs\dlc-windowsGPU\lib\site-packages\tensorflow\python\client\session.py", line 1075, in _run
#     raise RuntimeError('Attempted to use a closed Session.')
# RuntimeError: Attempted to use a closed Session.
# The network is now trained and ready to evaluate. Use the function 'evaluate_network' to evaluate the network.
# log written
# log written

# %%
# ?deeplabcut.train_network

# %% [markdown]
# ## Start evaluating
# This funtion evaluates a trained model for a specific shuffle/shuffles at a particular state or all the states on the data set (images)
# and stores the results as .csv file in a subdirectory under **evaluation-results**

# %%
start = datetime.datetime.now()
write_log(str(start) + "***evaluate_network start")

deeplabcut.evaluate_network(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***evaluate_network end")
write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7], [8]],
#  'all_joints_names': ['Nose',
#                       'Pellet',
#                       'DomInside',
#                       'DomOutside',
#                       'Index',
#                       'Middle',
#                       'Ring',
#                       'Pinky',
#                       'OtherHand'],
#  'batch_size': 4,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_gopro3lensJul8\\gopro3lens_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_gopro3lensJul8\\Documentation_data-gopro3lens_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 9,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08\\dlc-models\\iteration-0\\gopro3lensJul8-trainset90shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'topheight': 400,
#  'use_gt_segm': False,
#  'video': False,
#  'video_batch': False,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Running  DeepCut_resnet50_gopro3lensJul8shuffle1_120000  with # of trainingiterations: 120000
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\dlc-models\iteration-0\gopro3lensJul8-trainset90shuffle1\train\snapshot-120000
# Analyzing data...
# 204it [01:01,  3.21it/s]
# Done and results stored for snapshot:  snapshot-120000
# Results for 120000  training iterations: 90 1 train error: 9.03 pixels. Test error: 29.88  pixels.
# With pcutoff of 0.3  train error: 8.25 pixels. Test error: 19.24 pixels
# Thereby, the errors are given by the average distances between the labels by DLC and the scorer.
# The network is evaluated and the results are stored in the subdirectory 'evaluation_results'.
# If it generalizes well, choose the best model for prediction and update the config file with the appropriate index for the 'snapshotindex'.
# Use the function 'analyze_video' to make predictions on new videos.
# Otherwise consider retraining the network (see DeepLabCut workflow Fig 2)
# log written
# log written

# %%
Results for 120000  training iterations: 90 1 train error: 9.03 pixels. Test error: 29.88  pixels.
With pcutoff of 0.3  train error: 8.25 pixels. Test error: 19.24 pixels

# %% [markdown]
# ## Start Analyzing videos
# This function analyzes the new video. The user can choose the best model from the evaluation results and specify the correct snapshot index for the variable **snapshotindex** in the **config.yaml** file. Otherwise, by default the most recent snapshot is used to analyse the video.
#
# The results are stored in hd5 file in the same directory where the video resides.

# %%
# videofile_path = [r"C:\Users\vjj14\Downloads\compressed25.mp4"] #Enter the list of videos to analyze.
videos=[[r"C:\Users\vjj14\Documents\GoProLens\3lens\gp2.7k3lensA1.MP4"], [r"C:\Users\vjj14\Documents\GoProLens\3lens\gp2.7k3lensB1.MP4"],  [r"C:\Users\vjj14\Documents\GoProLens\3lens\GX016321.MP4"]]
for videofile_path in videos:
    start = datetime.datetime.now()
    write_log(str(start) + "***analyze_videos start")
    write_log("   VIDEO: " + str(videofile_path))

    deeplabcut.analyze_videos(path_config_file,videofile_path, destfolder=r"C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos")

    end = datetime.datetime.now()
    write_log(str(end) + "***analyze_videos end")
    write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# log written
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7], [8]],
#  'all_joints_names': ['Nose',
#                       'Pellet',
#                       'DomInside',
#                       'DomOutside',
#                       'Index',
#                       'Middle',
#                       'Ring',
#                       'Pinky',
#                       'OtherHand'],
#  'batch_size': 1,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_gopro3lensJul8\\gopro3lens_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_gopro3lensJul8\\Documentation_data-gopro3lens_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 9,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08\\dlc-models\\iteration-0\\gopro3lensJul8-trainset90shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'topheight': 400,
#  'use_gt_segm': False,
#  'video': False,
#  'video_batch': False,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Using snapshot-120000 for model C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\dlc-models\iteration-0\gopro3lensJul8-trainset90shuffle1
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\dlc-models\iteration-0\gopro3lensJul8-trainset90shuffle1\train\snapshot-120000
# Starting to analyze %  C:\Users\vjj14\Documents\GoProLens\3lens\gp2.7k3lensA1.MP4
# Loading  C:\Users\vjj14\Documents\GoProLens\3lens\gp2.7k3lensA1.MP4
# Duration of video [s]:  142.32 , recorded with  119.88 fps!
# Overall # of frames:  17061  found with (before cropping) frame dimensions:  2704 1520
# Starting to extract posture
# 17170it [46:24,  6.09it/s]
# Detected frames:  17061
# Saving results in C:\Users\vjj14\Documents\GoProLens\3lens...
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'.
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract any outlier frames!
# log written
# log written
# log written
# log written
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7], [8]],
#  'all_joints_names': ['Nose',
#                       'Pellet',
#                       'DomInside',
#                       'DomOutside',
#                       'Index',
#                       'Middle',
#                       'Ring',
#                       'Pinky',
#                       'OtherHand'],
#  'batch_size': 4,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_gopro3lensJul8\\gopro3lens_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_gopro3lensJul8\\Documentation_data-gopro3lens_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 9,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08\\dlc-models\\iteration-0\\gopro3lensJul8-trainset90shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'topheight': 400,
#  'use_gt_segm': False,
#  'video': False,
#  'video_batch': False,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Using snapshot-120000 for model C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\dlc-models\iteration-0\gopro3lensJul8-trainset90shuffle1
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\dlc-models\iteration-0\gopro3lensJul8-trainset90shuffle1\train\snapshot-120000
# Starting to analyze %  C:\Users\vjj14\Documents\GoProLens\3lens\gp2.7k3lensB1.MP4
# Loading  C:\Users\vjj14\Documents\GoProLens\3lens\gp2.7k3lensB1.MP4
# Duration of video [s]:  237.68 , recorded with  119.88 fps!
# Overall # of frames:  28493  found with (before cropping) frame dimensions:  2704 1520
# Starting to extract posture
# 28684it [1:16:10,  6.35it/s]
# Detected frames:  28493
# Saving results in C:\Users\vjj14\Documents\GoProLens\3lens...
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'.
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract any outlier frames!
# log written
# log written
# log written
# log written
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7], [8]],
#  'all_joints_names': ['Nose',
#                       'Pellet',
#                       'DomInside',
#                       'DomOutside',
#                       'Index',
#                       'Middle',
#                       'Ring',
#                       'Pinky',
#                       'OtherHand'],
#  'batch_size': 4,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_gopro3lensJul8\\gopro3lens_vj90shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\vjj14\\.conda\\envs\\dlc-windowsGPU\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_gopro3lensJul8\\Documentation_data-gopro3lens_90shuffle1.pickle',
#  'min_input_size': 64,
#  'minsize': 100,
#  'mirror': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 9,
#  'optimizer': 'sgd',
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08',
#  'regularize': False,
#  'rightwidth': 400,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\vjj14\\Desktop\\DeepLabCut\\gopro3lens-vj-2019-07-08\\dlc-models\\iteration-0\\gopro3lensJul8-trainset90shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'topheight': 400,
#  'use_gt_segm': False,
#  'video': False,
#  'video_batch': False,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Using snapshot-120000 for model C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\dlc-models\iteration-0\gopro3lensJul8-trainset90shuffle1
# INFO:tensorflow:Restoring parameters from C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\dlc-models\iteration-0\gopro3lensJul8-trainset90shuffle1\train\snapshot-120000
# Starting to analyze %  C:\Users\vjj14\Documents\GoProLens\3lens\GX016321.MP4
# Loading  C:\Users\vjj14\Documents\GoProLens\3lens\GX016321.MP4
# Duration of video [s]:  208.0 , recorded with  239.76 fps!
# Overall # of frames:  49871  found with (before cropping) frame dimensions:  1920 1080
# Starting to extract posture
#   0%|                                                     | 0/49871 [00:00<?, ?it/s]
# Detected frames:  225
#   1%|▍                                          | 498/49871 [00:18<30:20, 27.12it/s]
# Saving results in C:\Users\vjj14\Documents\GoProLens\3lens...
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'.
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract any outlier frames!
# log written
# log written

# %%
# ?deeplabcut.analyze_videos
# Out:
#  16%|████████████▎                                                                | 2480/15561 [03:30<17:57, 12.14it/s]

# %% [markdown]
# ## Extract outlier frames [optional step]
# This is an optional step and is used only when the evaluation results are poor i.e. the labels are incorrectly predicted. In such a case, the user can use the following function to extract frames where the labels are incorrectly predicted. Make sure to provide the correct value of the "iterations" as it will be used to create the unique directory where the extracted frames will be saved.

# %%
alg = 'uncertain'
param = 0.0002 #epsilon or p_bound

start = datetime.datetime.now()
write_log(str(start) + "***extract_outlier_frames start")

deeplabcut.extract_outlier_frames(path_config_file, videofile_path, outlieralgorithm=alg, p_bound=param)
num_frames = prompt_with_timeout("number of frames selected?")
write_log("   VIDEOS: {0}, ALGORITHM: {1}, PARAMETER: {2}, NUM FRAMES: {3}".format(str(videofile_path), alg, param, num_frames))

end = datetime.datetime.now()
write_log(str(end) + "***extract_outlier_frames start")
write_log("   time elapsed:" + str(end-start))
# Out:
# network parameters: DeepCut_resnet50_frontslowmoJun5shuffle1_28000
# Method  uncertain  found  12  putative outlier frames.
# Do you want to proceed with extracting  200  of those?
# If this list is very large, perhaps consider changing the paramters (start, stop, p_bound, comparisonbodyparts) or use a different method.
# yes/noyes
# Frames from video 1080p  already extracted (more will be added)!
# Loading video...
# Duration of video [s]:  518.6666666666666 , recorded @  30.0 fps!
# Overall # of frames:  15560 with (cropped) frame dimensions:
# Kmeans-quantization based extracting of frames from 0.0  seconds to 518.7  seconds.
# Let's select frames indices: [113, 154, 155, 156, 157, 158, 160, 161, 162, 13116, 13117, 13126]
# New video was added to the project! Use the function 'extract_frames' to select frames for labeling.
# The outlier frames are extracted. They are stored in the subdirectory labeled-data\1080p.
# Once you extracted frames for all videos, use 'refine_labels' to manually correct the labels.

# %%
# ?deeplabcut.extract_outlier_frames

# %% [markdown]
# ## Refine Labels [optional step]
# Following the extraction of outlier frames, the user can use the following function to move the predicted labels to the correct location. Thus augmenting the training dataset.

# %%
start = datetime.datetime.now()
write_log(str(start) + "***refine_frames start")

# %gui wx
deeplabcut.refine_labels(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***refine_frames end")
write_log("   time elapsed:" + str(end-start))
# Out:
# ERROR:root:Cannot activate multiple GUI eventloops
# Windows
# Checking labels if they are outside the image
# A training dataset file is already found for this video. The refined machine labels are merged to this data!
# Closing... The refined labels are stored in a subdirectory under labeled-data. Use the function 'merge_datasets' to augment the training dataset, and then re-train a network using create_training_dataset followed by train_network!

# %%
#Once all folders are relabeled, check them and advance. See how to check labels, above!
start = datetime.datetime.now()
write_log(str(start) + "***merge_datasets start")

deeplabcut.merge_datasets(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***merge_datasets end")
write_log("   time elapsed:" + str(end-start))
# Out:
# Merged data sets and updated refinement iteration to 2.
# Now you can create a new training set for the expanded annotated images (use create_training_dataset).

# %% [markdown]
# ## Create a new iteration of training dataset [optional step]
# Following the refine labels, append these frames to the original dataset to create a new iteration of training dataset.

# %%
start = datetime.datetime.now()
write_log(str(start) + "***create_training_dataset start")

deeplabcut.create_training_dataset(path_config_file)

end = datetime.datetime.now()
write_log(str(end) + "***create_training_dataset end")
write_log("   time elapsed:" + str(end-start))
# Out:
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!

# %% [markdown]
# ## Create labeled video
# This funtion is for visualiztion purpose and can be used to create a video in .mp4 format with labels predicted by the network. This video is saved in the same directory where the original video resides.

# %%
# videos=[LIST OF VIDEOS]
for videofile_path in videos:
    start = datetime.datetime.now()
    write_log(str(start) + "***create_labeled_video start")
    write_log("   VIDEOS: {}".format(str(videofile_path)))

    deeplabcut.create_labeled_video(path_config_file,videofile_path, destfolder=r"C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos")

    end = datetime.datetime.now()
    write_log(str(end) + "***create_labeled_video end")
    write_log("   time elapsed:" + str(end-start))
# Out:
# log written
# log written
# Starting %  C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos ['C:\\Users\\vjj14\\Documents\\GoProLens\\3lens\\gp2.7k3lensA1.MP4']
# Loading  C:\Users\vjj14\Documents\GoProLens\3lens\gp2.7k3lensA1.MP4 and data.
# False 0 2704 0 1520
# 17061
# Duration of video [s]:  142.32 , recorded with  119.88 fps!
# Overall # of frames:  17061 with cropped frame dimensions:  2704 1520
# Generating frames and creating video.
# 100%|█████████████████████████████████████████| 17061/17061 [10:04<00:00, 27.67it/s]
# log written
# log written
# log written
# log written
# Starting %  C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos ['C:\\Users\\vjj14\\Documents\\GoProLens\\3lens\\gp2.7k3lensB1.MP4']
# Loading  C:\Users\vjj14\Documents\GoProLens\3lens\gp2.7k3lensB1.MP4 and data.
# False 0 2704 0 1520
# 28493
# Duration of video [s]:  237.68 , recorded with  119.88 fps!
# Overall # of frames:  28493 with cropped frame dimensions:  2704 1520
# Generating frames and creating video.
# 100%|█████████████████████████████████████████| 28493/28493 [17:06<00:00, 27.75it/s]
# log written
# log written
# log written
# log written
# Starting %  C:\Users\vjj14\Desktop\DeepLabCut\gopro3lens-vj-2019-07-08\videos ['C:\\Users\\vjj14\\Documents\\GoProLens\\3lens\\GX016321.MP4']
# Loading  C:\Users\vjj14\Documents\GoProLens\3lens\GX016321.MP4 and data.
# False 0 1920 0 1080
# 49871
# Duration of video [s]:  0.94 , recorded with  239.76 fps!
# Overall # of frames:  225 with cropped frame dimensions:  1920 1080
# Generating frames and creating video.
# 100%|█████████████████████████████████████████████| 225/225 [00:04<00:00, 49.28it/s]
# log written
# log written

# %%
# ?deeplabcut.create_labeled_video

# %% [markdown]
# ## Plot the trajectories of the analyzed videos
# This function plots the trajectories of all the body parts across the entire video. Each body part is identified by a unique color.

# %%
videofile_path
# Out:
# ['C:\\Users\\vjj14\\Desktop\\DeepLabCut\\frontslowmo-vj-2019-06-05\\videos\\1080p.MOV']

# %%
# %matplotlib notebook 
#for making interactive plots.
deeplabcut.plot_trajectories(path_config_file,videofile_path)

# %%
# ?deeplabcut.plot_trajectories

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pandas analysis of Data

# %%
df = pd.read_hdf(r"PATH TO .h5 FILE")
df.head(5)
# Out:
# scorer    DeepCut_resnet50_frontslowmoJun5shuffle1_30000                \
# bodyparts                                       LeftHand
# coords                                                 x             y
# count                                       15560.000000  15560.000000
# mean                                          971.243753    725.853752
# std                                           171.896374    139.390499
# min                                            -3.870381      0.415488
# 25%                                           914.894261    649.265245
# 50%                                          1024.541650    783.569860
# 75%                                          1064.598903    821.210082
# max                                          1611.307688   1088.421771
#
# scorer                                                             \
# bodyparts                   RightHand
# coords       likelihood             x             y    likelihood
# count      15560.000000  15560.000000  15560.000000  15560.000000
# mean           0.699717    906.089441    738.766505      0.503567
# std            0.357561    156.673818    166.830793      0.400728
# min            0.000027    319.477097      1.081914      0.000040
# 25%            0.397388    850.580156    651.611459      0.060324
# 50%            0.910440    905.468754    778.514918      0.466857
# 75%            0.986921    940.134475    858.174915      0.949224
# max            0.999329   1609.412701   1092.391703      0.999041
#
# scorer                                                             \
# bodyparts          Nose                                    Pellet
# coords                x             y    likelihood             x
# count      15560.000000  15560.000000  15560.000000  15560.000000
# mean         931.766309    656.488581      0.671245    957.103689
# std          169.306891    191.976523      0.363396    159.386299
# min          298.748627     -0.059892      0.000104     -5.040360
# 25%          909.805872    595.394240      0.306699    922.235798
# 50%          918.396317    703.317179      0.875269    939.903313
# 75%          928.343641    794.728728      0.960582    953.739810
# max         1623.930874   1088.734671      0.998151   1613.409633
#
# scorer
# bodyparts
# coords                y    likelihood
# count      15560.000000  15560.000000
# mean         811.306070      0.322458
# std          177.523694      0.418997
# min            0.012989      0.000098
# 25%          671.503496      0.027885
# 50%          847.006353      0.048265
# 75%          940.497040      0.954270
# max         1089.468144      0.997180

# %%
df.describe()
# Out:
# scorer    DeepCut_resnet50_front4k60fpszoom3.0_TrimJun3shuffle1_286000  \
# bodyparts                                                     LeftHand
# coords                                                               x
# count                                             612.000000
# mean                                             1294.587569
# std                                               566.489027
# min                                                -0.173059
# 25%                                               955.338525
# 50%                                              1458.549845
# 75%                                              1644.293059
# max                                              2161.044888
#
# scorer                                                                    \
# bodyparts                             RightHand
# coords               y  likelihood            x            y  likelihood
# count       612.000000  612.000000   612.000000   612.000000  612.000000
# mean       2455.822662    0.042246   609.627308  2811.817150    0.078364
# std         890.589556    0.138305   523.969844   763.555947    0.202453
# min           1.988913    0.000032     0.665848    76.401595    0.000153
# 25%        1989.080632    0.000861     3.883312  2168.396138    0.001087
# 50%        2089.116435    0.002397   764.576838  2395.076544    0.003136
# 75%        3421.296761    0.011128   970.543810  3556.132724    0.019450
# max        3840.645847    0.977641  2139.572770  3840.410774    0.992057
#
# scorer                                                                     \
# bodyparts         Nose                                Pellet
# coords               x            y  likelihood            x            y
# count       612.000000   612.000000  612.000000   612.000000   612.000000
# mean       1000.140640  2138.825481    0.222379  1161.420468  3607.459208
# std         249.147238   615.631056    0.313997   635.214989   435.197877
# min           0.269251   865.347540    0.000097     2.184450  1940.036492
# 25%         990.724893  1820.097459    0.004228   736.731850  3637.395378
# 50%        1030.763698  1986.446780    0.050586   963.540944  3822.212681
# 75%        1069.846140  2166.098999    0.300523  1822.975545  3837.997508
# max        2152.967607  3841.093842    0.998524  2158.995823  3841.865475
#
# scorer
# bodyparts
# coords     likelihood
# count      612.000000
# mean         0.364173
# std          0.308807
# min          0.000428
# 25%          0.070970
# 50%          0.276980
# 75%          0.658898
# max          0.989263
